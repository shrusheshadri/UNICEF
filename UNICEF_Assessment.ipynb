# %% [markdown]
# <a href="https://colab.research.google.com/github/shrusheshadri/UNICEF/blob/main/UNICEF_Assessment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Position:Learning and Skills Data Analyst Consultant – Req. #581598

# %% [markdown]
# # Task
# Merge the three files "countries_file1.csv", "countries_file2.csv", and "countries_file3.csv" based on a consistent country identifier column.

# %% [markdown]
# ## Load the data
#
# ### Subtask:
# Load the three files into separate DataFrames.

# %% [markdown]
# **Reasoning**:
# Import pandas and load the three CSV files into separate DataFrames as instructed.

# %% [markdown]
# # Task
# Clean and merge the datasets in "/GLOBAL_DATAFLOW_2018-2022.xlsx", "/On-track and off-track countries.xlsx", and "/WPP2022_GEN_F01_DEMOGRAPHIC_INDICATORS_COMPACT_REV1.xlsx" using consistent country identifiers. For the data from "/GLOBAL_DATAFLOW_2018-2022.xlsx" and "/On-track and off-track countries.xlsx", filter for 'ANC4' and 'SBA' coverage estimates from 2018 to 2022 and use the most recent estimate within this range per country.

# %% [markdown]
# ## Load the data
#
# ### Subtask:
# Load the three specified Excel files into separate DataFrames.

# %% [markdown]
# **Reasoning**:
# Import pandas and load the three specified Excel files into separate DataFrames, then display the head of each DataFrame as instructed.

# %%
import pandas as pd

df_global_dataflow = pd.read_excel("/GLOBAL_DATAFLOW_2018-2022.xlsx")
df_on_track = pd.read_excel("/On-track and off-track countries.xlsx")
df_demographic = pd.read_excel("/WPP2022_GEN_F01_DEMOGRAPHIC_INDICATORS_COMPACT_REV1.xlsx")

display(df_global_dataflow.head())
display(df_on_track.head())
display(df_demographic.head())
# Out:
#               Time period                                         Unnamed: 1  \
# 0         Geographic area                                          Indicator
# 1                     NaN                                                NaN
# 2  (SDGRC) Central Africa  Antenatal care 4+ visits - percentage of women...
# 3  (SDGRC) Central Africa  Skilled birth attendant - percentage of delive...
# 4  (SDGRC) Eastern Africa  Antenatal care 4+ visits - percentage of women...
#
#   Unnamed: 2  2022  2021  2020  2019  2018
# 0        Sex   NaN   NaN   NaN   NaN   NaN
# 1        NaN   NaN   NaN   NaN   NaN   NaN
# 2      Total  56.6  55.9  55.3  54.6    54
# 3      Total  67.6  65.9    64    62  59.8
# 4      Total  51.4  50.4  49.1  48.1  46.9
#   ISO3Code OfficialName          Status.U5MR
# 0      AFG  Afghanistan  Acceleration Needed
# 1      AGO       Angola  Acceleration Needed
# 2      AIA     Anguilla             Achieved
# 3      ALB      Albania             Achieved
# ...

# %% [markdown]
# ## Clean and standardize country identifiers
#
# ### Subtask:
# Standardize the country identifier column in each DataFrame for consistent merging.

# %% [markdown]
# **Reasoning**:
# Examine the first few rows of each DataFrame to identify the correct header row and then reload the DataFrames with the correct header.

# %%
display(df_global_dataflow.head())
display(df_on_track.head())
display(df_demographic.head())

df_global_dataflow = pd.read_excel("/GLOBAL_DATAFLOW_2018-2022.xlsx", header=1)
df_on_track = pd.read_excel("/On-track and off-track countries.xlsx")
df_demographic = pd.read_excel("/WPP2022_GEN_F01_DEMOGRAPHIC_INDICATORS_COMPACT_REV1.xlsx", header=3)

display(df_global_dataflow.head())
display(df_on_track.head())
display(df_demographic.head())
# Out:
#               Time period                                         Unnamed: 1  \
# 0         Geographic area                                          Indicator
# 1                     NaN                                                NaN
# 2  (SDGRC) Central Africa  Antenatal care 4+ visits - percentage of women...
# 3  (SDGRC) Central Africa  Skilled birth attendant - percentage of delive...
# 4  (SDGRC) Eastern Africa  Antenatal care 4+ visits - percentage of women...
#
#   Unnamed: 2  2022  2021  2020  2019  2018
# 0        Sex   NaN   NaN   NaN   NaN   NaN
# 1        NaN   NaN   NaN   NaN   NaN   NaN
# 2      Total  56.6  55.9  55.3  54.6    54
# 3      Total  67.6  65.9    64    62  59.8
# 4      Total  51.4  50.4  49.1  48.1  46.9
#   ISO3Code OfficialName          Status.U5MR
# 0      AFG  Afghanistan  Acceleration Needed
# 1      AGO       Angola  Acceleration Needed
# 2      AIA     Anguilla             Achieved
# 3      ALB      Albania             Achieved
# ...

# %% [markdown]
# **Reasoning**:
# Identify the country identifier columns in each DataFrame and rename them to 'Country' for consistency.

# %%
print(df_global_dataflow.columns)
print(df_on_track.columns)
print(df_demographic.columns)

df_global_dataflow.rename(columns={'Geographic area': 'Country'}, inplace=True)
df_on_track.rename(columns={'OfficialName': 'Country'}, inplace=True)
df_demographic.rename(columns={'Unnamed: 4': 'Country'}, inplace=True)

display(df_global_dataflow.head())
display(df_on_track.head())
display(df_demographic.head())
# Out:
# Index(['Geographic area', 'Indicator', 'Sex', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7'],
#       dtype='object')
# Index(['ISO3Code', 'OfficialName', 'Status.U5MR'], dtype='object')
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25',
#        'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29',
#        'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33',
#        'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37',
#        'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41',
#        'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45',
# ...

# %% [markdown]
# **Reasoning**:
# Examine the unique values in the 'Country' column of each DataFrame to identify and standardize any inconsistencies in country naming.

# %%
print("Unique countries in df_global_dataflow:")
print(df_global_dataflow['Country'].unique())

print("\nUnique countries in df_on_track:")
print(df_on_track['Country'].unique())

print("\nUnique countries in df_demographic:")
print(df_demographic['Country'].unique())

df_global_dataflow['Country'] = df_global_dataflow['Country'].str.strip().str.lower()
df_on_track['Country'] = df_on_track['Country'].str.strip().str.lower()
df_demographic['Country'] = df_demographic['Country'].str.strip().str.lower()

print("\nUnique countries in df_global_dataflow after standardization:")
print(df_global_dataflow['Country'].unique())

print("\nUnique countries in df_on_track after standardization:")
print(df_on_track['Country'].unique())

print("\nUnique countries in df_demographic after standardization:")
print(df_demographic['Country'].unique())

display(df_global_dataflow.head())
display(df_on_track.head())
display(df_demographic.head())
# Out:
# Unique countries in df_global_dataflow:
# [nan '(SDGRC) Central Africa' '(SDGRC) Eastern Africa'
#  '(SDGRC) North Africa' '(SDGRC) Southern Africa'
#  '(SDGRC) United Nations Economic Commission for Africa'
#  '(SDGRC) West Africa' 'Afghanistan' 'Africa' 'African Union' 'Albania'
#  'Algeria' 'Americas' 'Anguilla' 'Antigua and Barbuda'
#  'Arab Maghreb Union (AMU)' 'Arab States' 'Argentina'
#  'Asia and the Pacific' 'Australia' 'Austria' 'Azerbaijan' 'Bahamas'
#  'Bahrain' 'Bangladesh' 'Barbados' 'Belarus' 'Belize' 'Benin' 'Bermuda'
#  'Bhutan' 'Bolivia (Plurinational State of)' 'Bosnia and Herzegovina'
#  'Botswana' 'Brazil' 'Brunei Darussalam' 'Bulgaria' 'Burkina Faso'
#  'Burundi' 'Cabo Verde' 'Cambodia' 'Cameroon' 'Canada' 'Caribbean'
#  'Central Africa (African Union)' 'Central African Republic'
#  'Central America' 'Central Asia' 'Central and Southern Asia' 'Chad'
#  'Chile' 'China' 'Colombia'
#  'Common Market for Eastern and Southern Africa (COMESA)'
# ...

# %% [markdown]
# **Reasoning**:
# Further standardize the country names by removing parenthesized text and regional groupings from `df_global_dataflow` and cleaning up irrelevant entries in `df_demographic`. Display unique countries and the head of each dataframe to verify the changes.

# %%
import re

# Remove parenthesized text and leading/trailing spaces from df_global_dataflow
df_global_dataflow['Country'] = df_global_dataflow['Country'].apply(lambda x: re.sub(r'\(.*?\)', '', str(x)).strip() if pd.notna(x) else x)

# Remove rows from df_global_dataflow that are not countries
regions_to_remove = ['africa', 'african union', 'americas', 'anguilla', 'arab maghreb union (amu)', 'arab states', 'asia and the pacific', 'caribbean', 'central africa (african union)', 'central america', 'central asia', 'central and southern asia', 'common market for eastern and southern africa (comesa)', 'community of sahel-saharan states (cen-sad)', 'east african community (eac)', 'east asia and pacific', 'east and southern africa', 'eastern africa', 'eastern africa (african union)', 'eastern asia', 'eastern europe and central asia', 'eastern mediterranean', 'eastern and south-eastern asia', 'eastern and southern africa', 'economic community of central african states (eccas)', 'economic community of west african states (ecowas 2025)', 'economic community of west african states (ecowas)', 'europe', 'europe and central asia', 'intergovernmental authority on development (igad)', 'latin america and the caribbean', 'least developed countries (ldc)', 'middle africa', 'middle east and north africa', 'north america', 'northern africa', 'northern africa (african union)', 'northern africa and western asia', 'northern america', 'oceania', 'oceania (exc. australia and new zealand)', 'sdg regions - global', 'south america', 'south asia', 'south sudan', 'south-east asia', 'south-eastern asia', 'southern africa', 'southern africa (african union)', 'southern african development community (sadc)', 'southern asia', 'sub-saharan africa', 'unicef programme regions - global', 'unicef reporting regions - global', 'west and central africa', 'western africa', 'western africa (african union)', 'western asia', 'western europe', 'western pacific', 'world bank (high income)', 'world bank (low income)', 'world bank (lower middle income)', 'world bank (upper middle income)', 'footnotes', 'unit multiplier: units', 'unit of measure: %', 'observation confidentaility: free', 'time period activity related to when the da', 'current age: 15 to 49 years old']

df_global_dataflow = df_global_dataflow[~df_global_dataflow['Country'].isin(regions_to_remove)]

# Clean up irrelevant entries in df_demographic
demographic_irrelevant = ['united nations', 'population division', 'department of economic and social affairs', 'world population prospects 2022', 'country']
df_demographic = df_demographic[~df_demographic['Country'].isin(demographic_irrelevant)]
df_demographic = df_demographic.dropna(subset=['Country'])


print("\nUnique countries in df_global_dataflow after further standardization:")
print(df_global_dataflow['Country'].unique())

print("\nUnique countries in df_on_track after further standardization:")
print(df_on_track['Country'].unique())

print("\nUnique countries in df_demographic after further standardization:")
print(df_demographic['Country'].unique())

display(df_global_dataflow.head())
display(df_on_track.head())
display(df_demographic.head())
# Out:
# Unique countries in df_global_dataflow after further standardization:
# [nan 'central africa' 'north africa'
#  'united nations economic commission for africa' 'west africa'
#  'afghanistan' 'albania' 'algeria' 'antigua and barbuda'
#  'arab maghreb union' 'argentina' 'australia' 'austria' 'azerbaijan'
#  'bahamas' 'bahrain' 'bangladesh' 'barbados' 'belarus' 'belize' 'benin'
#  'bermuda' 'bhutan' 'bolivia' 'bosnia and herzegovina' 'botswana' 'brazil'
#  'brunei darussalam' 'bulgaria' 'burkina faso' 'burundi' 'cabo verde'
#  'cambodia' 'cameroon' 'canada' 'central african republic' 'chad' 'chile'
#  'china' 'colombia' 'common market for eastern and southern africa'
#  'community of sahel-saharan states' 'comoros' 'costa rica' 'croatia'
#  'cuba' 'cyprus' "côte d'ivoire" 'democratic republic of the congo'
#  'denmark' 'dominica' 'dominican republic' 'east african community'
#  'economic community of central african states'
# ...

# %% [markdown]
# **Reasoning**:
# Further clean `df_global_dataflow` by removing region names that were not caught by the previous filter and remove rows with NaN in the 'Country' column in all dataframes. Display unique countries and the head of each dataframe to verify the changes.

# %%
regions_to_remove_further = ['central africa', 'north africa', 'united nations economic commission for africa', 'west africa', 'arab maghreb union', 'common market for eastern and southern africa', 'community of sahel-saharan states', 'east african community', 'economic community of central african states', 'economic community of west african states', 'intergovernmental authority on development', 'least developed countries', 'southern african development community', 'world bank', 'time period activity related to when the data are collected: end of fieldwork']

df_global_dataflow = df_global_dataflow[~df_global_dataflow['Country'].isin(regions_to_remove_further)]

df_global_dataflow = df_global_dataflow.dropna(subset=['Country'])
df_on_track = df_on_track.dropna(subset=['Country'])
df_demographic = df_demographic.dropna(subset=['Country'])


print("\nUnique countries in df_global_dataflow after further standardization:")
print(df_global_dataflow['Country'].unique())

print("\nUnique countries in df_on_track after further standardization:")
print(df_on_track['Country'].unique())

print("\nUnique countries in df_demographic after further standardization:")
print(df_demographic['Country'].unique())

display(df_global_dataflow.head())
display(df_on_track.head())
display(df_demographic.head())
# Out:
# Unique countries in df_global_dataflow after further standardization:
# ['afghanistan' 'albania' 'algeria' 'antigua and barbuda' 'argentina'
#  'australia' 'austria' 'azerbaijan' 'bahamas' 'bahrain' 'bangladesh'
#  'barbados' 'belarus' 'belize' 'benin' 'bermuda' 'bhutan' 'bolivia'
#  'bosnia and herzegovina' 'botswana' 'brazil' 'brunei darussalam'
#  'bulgaria' 'burkina faso' 'burundi' 'cabo verde' 'cambodia' 'cameroon'
#  'canada' 'central african republic' 'chad' 'chile' 'china' 'colombia'
#  'comoros' 'costa rica' 'croatia' 'cuba' 'cyprus' "côte d'ivoire"
#  'democratic republic of the congo' 'denmark' 'dominica'
#  'dominican republic' 'ecuador' 'egypt' 'el salvador' 'estonia' 'eswatini'
#  'ethiopia' 'fiji' 'finland' 'france' 'gabon' 'gambia' 'georgia' 'germany'
#  'ghana' 'greece' 'grenada' 'guinea' 'guinea-bissau' 'guyana' 'honduras'
#  'iceland' 'india' 'indonesia' 'iraq' 'ireland' 'italy' 'jamaica' 'japan'
# ...

# %% [markdown]
# **Reasoning**:
# The country names are now largely standardized, but there are still some inconsistencies and irrelevant entries in `df_demographic`. Further clean `df_demographic` by removing rows that appear to be metadata or summary information based on the unique values observed. Display unique countries and the head of each dataframe to verify the changes.

# %%
demographic_irrelevant_more = [
    'file gen/01/rev1: demographic indicators by region, subregion, country or area',
    'estimates, 1950 - 2021',
    'pop/db/wpp/rev.2022/gen/f01/rev.1',
    '© july 2022 by united nations, made available under creative commons license 4.0',
    'suggested citation: united nations, department of economic and social affairs, population division (2022). world population prospects 2022.',
    'note: regional aggregates are based on the latest available country classification.',
    'index', 'variant', 'region, subregion, country or area *', 'notes',
    'location code', 'iso3 code', 'location type', 'parent code', 'year', 'population (thousands)',
    'annual population change (percent)', 'medium fertility', 'low fertility', 'high fertility',
    'constant fertility', 'instant replacement fertility', 'zero migration',
    'median age (years)', 'natural change (thousands)', 'rate of natural change (per 1,000 population)',
    'births (thousands)', 'crude birth rate (per 1,000 population)', 'deaths (thousands)',
    'crude death rate (per 1,000 population)',
    'total fertility rate (live births per woman)', 'net number of migrants (thousands)',
    'net migration rate (per 1,000 population)', 'sex ratio (males per 100 females) as of 1 july',
    'population density (persons per square km) as of 1 july', 'median age (years) as of 1 july',
    'mean age childbearing (years) as of 1 july', 'life expectancy at birth, both sexes (years)',
    'life expectancy at birth, male (years)', 'life expectancy at birth, female (years)',
    'life expectancy at age 15, both sexes (years)', 'life expectancy at age 15, male (years)',
    'life expectancy at age 15, female (years)', 'life expectancy at age 65, both sexes (years)',
    'life expectancy at age 65, male (years)', 'life expectancy at age 65, female (years)',
    'infant mortality rate (deaths per 1,000 live births)',
    'under-five mortality rate (deaths per 1,000 live births)',
    'mortality before age 60 (deaths per 1,000 live births)',
    'mortality between age 15 and 60, both sexes (deaths per 1,000 population)',
    'male mortality between age 15 and 60 (deaths under age 60 per 1,000 male population)',
    'female mortality between age 15 and 60 (deaths under age 60 per 1,000 female population)'
]

df_demographic = df_demographic[~df_demographic['Country'].isin(demographic_irrelevant_more)]
df_demographic = df_demographic.dropna(subset=['Country'])

print("\nUnique countries in df_global_dataflow after final standardization:")
print(df_global_dataflow['Country'].unique())

print("\nUnique countries in df_on_track after final standardization:")
print(df_on_track['Country'].unique())

print("\nUnique countries in df_demographic after final standardization:")
print(df_demographic['Country'].unique())

display(df_global_dataflow.head())
display(df_on_track.head())
display(df_demographic.head())
# Out:
# Unique countries in df_global_dataflow after final standardization:
# ['afghanistan' 'albania' 'algeria' 'antigua and barbuda' 'argentina'
#  'australia' 'austria' 'azerbaijan' 'bahamas' 'bahrain' 'bangladesh'
#  'barbados' 'belarus' 'belize' 'benin' 'bermuda' 'bhutan' 'bolivia'
#  'bosnia and herzegovina' 'botswana' 'brazil' 'brunei darussalam'
#  'bulgaria' 'burkina faso' 'burundi' 'cabo verde' 'cambodia' 'cameroon'
#  'canada' 'central african republic' 'chad' 'chile' 'china' 'colombia'
#  'comoros' 'costa rica' 'croatia' 'cuba' 'cyprus' "côte d'ivoire"
#  'democratic republic of the congo' 'denmark' 'dominica'
#  'dominican republic' 'ecuador' 'egypt' 'el salvador' 'estonia' 'eswatini'
#  'ethiopia' 'fiji' 'finland' 'france' 'gabon' 'gambia' 'georgia' 'germany'
#  'ghana' 'greece' 'grenada' 'guinea' 'guinea-bissau' 'guyana' 'honduras'
#  'iceland' 'india' 'indonesia' 'iraq' 'ireland' 'italy' 'jamaica' 'japan'
# ...

# %% [markdown]
# ## Filter and select recent data
#
# ### Subtask:
# Filter for 'ANC4' and 'SBA' coverage estimates from 2018 to 2022 and use the most recent estimate within this range per country.

# %% [markdown]
# **Reasoning**:
# I will start by filtering the `df_global_dataflow` DataFrame to include only the 'ANC4' and 'SBA' indicators. Then, I will melt the DataFrame to transform the year columns into 'Year' and 'Value' columns, and clean the data by dropping rows with missing values and converting the data types of 'Year' and 'Value' to numeric. This combines the first three steps of the subtask into one code block for efficiency.

# %%
df_global_dataflow_filtered = df_global_dataflow[
    df_global_dataflow['Indicator'].isin([
        'Antenatal care 4+ visits - percentage of women...',
        'Skilled birth attendant - percentage of delive...'
    ])
]

df_melted = df_global_dataflow_filtered.melt(
    id_vars=['Country', 'Indicator'],
    value_vars=['2018', '2019', '2020', '2021', '2022'],
    var_name='Year',
    value_name='Value'
)

df_melted.dropna(subset=['Value'], inplace=True)
df_melted['Year'] = pd.to_numeric(df_melted['Year'])
df_melted['Value'] = pd.to_numeric(df_melted['Value'], errors='coerce')
df_melted.dropna(subset=['Value'], inplace=True)

display(df_melted.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-10-3648667177.py in <cell line: 0>()
#       6 ]
#       7
# ----> 8 df_melted = df_global_dataflow_filtered.melt(
#       9     id_vars=['Country', 'Indicator'],
#      10     value_vars=['2018', '2019', '2020', '2021', '2022'],
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in melt(self, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#    9940         ignore_index: bool = True,
#    9941     ) -> DataFrame:
# -> 9942         return melt(
#    9943             self,
#    9944             id_vars=id_vars,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/reshape/melt.py in melt(frame, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#      72                 lab for lab, not_found in zip(labels, missing) if not_found
#      73             ]
# ...

# %% [markdown]
# **Reasoning**:
# The previous command failed because the column names for the years are not '2018' through '2022'. I need to inspect the column names of `df_global_dataflow_filtered` to identify the correct year columns and then use those in the `melt` function.

# %%
print(df_global_dataflow_filtered.columns)
# Out:
# Index(['Country', 'Indicator', 'Sex', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7'],
#       dtype='object')

# %% [markdown]
# **Reasoning**:
# The column names for the years are 'Unnamed: 3' through 'Unnamed: 7'. I will use these column names in the `melt` function and then proceed with cleaning and converting the data types, followed by finding the most recent estimate and pivoting the data as per the instructions. This combines the remaining steps of the subtask into one code block.

# %%
df_melted = df_global_dataflow_filtered.melt(
    id_vars=['Country', 'Indicator', 'Sex'],
    value_vars=['Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7'],
    var_name='Year_col',
    value_name='Value'
)

year_map = {
    'Unnamed: 3': 2018,
    'Unnamed: 4': 2019,
    'Unnamed: 5': 2020,
    'Unnamed: 6': 2021,
    'Unnamed: 7': 2022
}

df_melted['Year'] = df_melted['Year_col'].map(year_map)

df_melted.dropna(subset=['Value'], inplace=True)
df_melted['Value'] = pd.to_numeric(df_melted['Value'], errors='coerce')
df_melted.dropna(subset=['Value'], inplace=True)

df_melted_sorted = df_melted.sort_values(by=['Country', 'Indicator', 'Year'], ascending=[True, True, False])
df_most_recent = df_melted_sorted.drop_duplicates(subset=['Country', 'Indicator'], keep='first')

df_pivot = df_most_recent.pivot(index='Country', columns='Indicator', values='Value')

display(df_pivot.head())
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# **Reasoning**:
# The pivoted DataFrame is empty, which indicates that there might be an issue with the data or the pivoting step. I need to inspect the `df_most_recent` DataFrame to understand why the pivot operation resulted in an empty DataFrame.

# %%
display(df_most_recent.head())
# Out:
# Empty DataFrame
# Columns: [Country, Indicator, Sex, Year_col, Value, Year]
# Index: []

# %% [markdown]
# **Reasoning**:
# The `df_most_recent` DataFrame is empty, which means that no data remained after the cleaning and filtering steps. I need to go back and inspect the intermediate `df_melted` DataFrame to understand where the data was lost.

# %%
display(df_melted.head())
# Out:
# Empty DataFrame
# Columns: [Country, Indicator, Sex, Year_col, Value, Year]
# Index: []

# %% [markdown]
# **Reasoning**:
# The `df_melted` DataFrame is also empty, which means the data was lost during the melting process or the initial filtering for 'ANC4' and 'SBA' indicators. I need to inspect the `df_global_dataflow_filtered` DataFrame to see if it contains any data after the initial filtering.

# %%
display(df_global_dataflow_filtered.head())
# Out:
# Empty DataFrame
# Columns: [Country, Indicator, Sex, Unnamed: 3, Unnamed: 4, Unnamed: 5, Unnamed: 6, Unnamed: 7]
# Index: []

# %% [markdown]
# **Reasoning**:
# The `df_global_dataflow_filtered` DataFrame is empty, indicating that the initial filtering for 'ANC4' and 'SBA' indicators resulted in no matching rows. I need to check the unique values in the 'Indicator' column of the original `df_global_dataflow` DataFrame to confirm the exact names of the indicators and identify why the filtering is not working as expected.

# %%
print(df_global_dataflow['Indicator'].unique())
# Out:
# ['Antenatal care 4+ visits - percentage of women (aged 15-49 years) attended at least four times during pregnancy by any provider'
#  'Skilled birth attendant - percentage of deliveries attended by skilled health personnel']

# %% [markdown]
# **Reasoning**:
# The unique values in the 'Indicator' column are exactly as expected. The issue must be with how the filtering is being applied. I will re-execute the filtering step, ensuring the indicator names are precisely matched. I will also include the subsequent steps of melting, cleaning, finding the most recent estimate, and pivoting in the same code block, as the previous attempts failed at the filtering stage.

# %%
df_global_dataflow_filtered = df_global_dataflow[
    df_global_dataflow['Indicator'].isin([
        'Antenatal care 4+ visits - percentage of women (aged 15-49 years) attended at least four times during pregnancy by any provider',
        'Skilled birth attendant - percentage of deliveries attended by skilled health personnel'
    ])
]

df_melted = df_global_dataflow_filtered.melt(
    id_vars=['Country', 'Indicator', 'Sex'],
    value_vars=['Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7'],
    var_name='Year_col',
    value_name='Value'
)

year_map = {
    'Unnamed: 3': 2018,
    'Unnamed: 4': 2019,
    'Unnamed: 5': 2020,
    'Unnamed: 6': 2021,
    'Unnamed: 7': 2022
}

df_melted['Year'] = df_melted['Year_col'].map(year_map)

df_melted.dropna(subset=['Value'], inplace=True)
df_melted['Value'] = pd.to_numeric(df_melted['Value'], errors='coerce')
df_melted.dropna(subset=['Value'], inplace=True)

df_melted_sorted = df_melted.sort_values(by=['Country', 'Indicator', 'Year'], ascending=[True, True, False])
df_most_recent = df_melted_sorted.drop_duplicates(subset=['Country', 'Indicator'], keep='first')

df_pivot = df_most_recent.pivot(index='Country', columns='Indicator', values='Value')

display(df_pivot.head())
# Out:
# Indicator            Antenatal care 4+ visits - percentage of women (aged 15-49 years) attended at least four times during pregnancy by any provider  \
# Country
# afghanistan                                                       20.9
# albania                                                           77.8
# algeria                                                           69.8
# antigua and barbuda                                                NaN
# argentina                                                         90.4
#
# Indicator            Skilled birth attendant - percentage of deliveries attended by skilled health personnel
# Country
# afghanistan                                                       58.8
# albania                                                           99.8
# algeria                                                           98.8
# antigua and barbuda                                               99.0
# ...

# %% [markdown]
# ## Merge the dataframes
#
# ### Subtask:
# Merge the processed DataFrames based on the standardized country identifiers.

# %% [markdown]
# **Reasoning**:
# Merge the processed dataframes based on the 'Country' column using outer joins and display the head of the final merged dataframe.

# %%
df_merged = pd.merge(df_pivot, df_on_track, on='Country', how='outer')
df_merged = pd.merge(df_merged, df_demographic, on='Country', how='outer')
display(df_merged.head())
# Out:
#        Country  \
# 0  afghanistan
# 1      albania
# 2      algeria
# 3      andorra
# 4       angola
#
#    Antenatal care 4+ visits - percentage of women (aged 15-49 years) attended at least four times during pregnancy by any provider  \
# 0                                               20.9
# 1                                               77.8
# 2                                               69.8
# 3                                                NaN
# 4                                                NaN
#
#    Skilled birth attendant - percentage of deliveries attended by skilled health personnel  \
# 0                                               58.8
# 1                                               99.8
# 2                                               98.8
# 3                                                NaN
# 4                                                NaN
#
#   ISO3Code          Status.U5MR Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# ...

# %% [markdown]
# ## Verify the merged data
#
# ### Subtask:
# Inspect the merged DataFrame to ensure the merge was successful and the filtering and selection of recent data were applied correctly.

# %% [markdown]
# **Reasoning**:
# Inspect the merged DataFrame as instructed by the subtask.

# %%
display(df_merged.head())
display(df_merged.info())
print(df_merged.shape)
print(df_merged[df_merged['Country'] == 'afghanistan'].T)
print(df_merged[df_merged['Country'].duplicated()].shape)
# Out:
#        Country  \
# 0  afghanistan
# 1      albania
# 2      algeria
# 3      andorra
# 4       angola
#
#    Antenatal care 4+ visits - percentage of women (aged 15-49 years) attended at least four times during pregnancy by any provider  \
# 0                                               20.9
# 1                                               77.8
# 2                                               69.8
# 3                                                NaN
# 4                                                NaN
#
#    Skilled birth attendant - percentage of deliveries attended by skilled health personnel  \
# 0                                               58.8
# 1                                               99.8
# 2                                               98.8
# 3                                                NaN
# 4                                                NaN
#
#   ISO3Code          Status.U5MR Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# ...

# %% [markdown]
# ## Save the merged data
#
# ### Subtask:
# Save the final merged and filtered DataFrame to a new file.

# %% [markdown]
# **Reasoning**:
# Save the merged dataframe to a CSV file.

# %%
df_merged.to_csv("merged_country_data.csv", index=False)

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   Three datasets were successfully loaded: `df_global_dataflow`, `df_on_track`, and `df_demographic`.
# *   Initial inspection revealed metadata and headers in `df_global_dataflow` and `df_demographic` that required cleaning.
# *   Country identifier columns were standardized to 'Country' across all DataFrames, and basic inconsistencies in casing and whitespace were resolved.
# *   Numerous regional groupings, metadata, and irrelevant entries were removed from the 'Country' columns in `df_global_dataflow` and `df_demographic`.
# *   Rows with missing 'Country' values were removed from all DataFrames.
# *   The `df_global_dataflow` DataFrame was filtered for 'Antenatal care 4+ visits - percentage of women (aged 15-49 years) attended at least four times during pregnancy by any provider' and 'Skilled birth attendant - percentage of deliveries attended by skilled health personnel' indicators within the 2018-2022 timeframe.
# *   The most recent estimate within the 2018-2022 range for 'ANC4' and 'SBA' was selected for each country.
# *   The filtered and selected data was pivoted to have 'Country' as the index and 'ANC4' and 'SBA' as columns.
# *   The processed `df_pivot` (containing ANC4 and SBA data), `df_on_track`, and `df_demographic` DataFrames were successfully merged using outer joins on the 'Country' column, resulting in a `df_merged` DataFrame with 207 rows and 69 columns.
# *   Verification confirmed the presence of columns from all original sources in `df_merged`, aligned by country, with no duplicate country entries.
# *   The final merged DataFrame was saved to "merged\_country\_data.csv" without the index.
#
# ### Insights or Next Steps
#
# *   The merged dataset provides a comprehensive view of maternal health coverage (ANC4, SBA), on/off-track status, and demographic indicators at the country level, which can be used for further analysis on factors influencing maternal health outcomes.
# *   Explore potential discrepancies or missing data points for specific countries in the merged dataset and consider strategies for imputation or exclusion based on the analysis objectives.
